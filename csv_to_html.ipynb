# %%
import pandas as pd

reader = pd.read_csv('./Resources/cities.csv')
cities_df = pd.DataFrame(reader)
cities_html = cities_df.to_html()

# %%
print(cities_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Max Temperature</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Humidity</th>
#       <th>Cloud %</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>poum</td>
#       <td>70.41</td>
#       <td>-20.2333</td>
#       <td>164.0167</td>
#       <td>71</td>
#       <td>99</td>
#       <td>9.78</td>
#       <td>NC</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>alofi</td>
#       <td>78.69</td>
#       <td>-19.0595</td>
#       <td>-169.9187</td>
#       <td>61</td>
#       <td>28</td>
#       <td>11.50</td>
#       <td>NU</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>kapaa</td>
#       <td>86.32</td>
#       <td>22.0752</td>
#       <td>-159.3190</td>
#       <td>72</td>
#       <td>20</td>
#       <td>5.01</td>
# ...
